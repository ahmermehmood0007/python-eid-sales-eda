# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install --upgrade notebook

# %%
print("ahmer")
# Out:
# ahmer

# %%
df= pd.read_csv('Eid Sales Data.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %%
# data cleaning:---

df.info()

df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB
# (11251, 15)

# %%
df.drop(['Status','unnamed1'],axis=1, inplace =True   )
# axis  us  pory column pr  apply  and  inplace  mean whole  line this  will be saved

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), str(8)
# memory usage: 1.1 MB

# %%
#  TO CHECK OUT NULL VALUES  
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values 
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.shape
# Out:
# (11239, 13)

# %%
#  initialize list  
data_test= [['Ahmer',11],['Mehmood',24],['Hassan', ],['hamza ',22]]

df_test=pd.DataFrame(data_test,columns=['Name','Age'])

df_test
# Out:
#       Name   Age
# 0    Ahmer  11.0
# 1  Mehmood  24.0
# 2   Hassan   NaN
# 3   hamza   22.0

# %%
df_test.dropna()
# Out:
#       Name   Age
# 0    Ahmer  11.0
# 1  Mehmood  24.0
# 3   hamza   22.0

# %%
df_test
# Out:
#       Name   Age
# 0    Ahmer  11.0
# 1  Mehmood  24.0
# 2   Hassan   NaN
# 3   hamza   22.0

# %%
df_test.dropna(inplace=True) # so that is why inplace true is necassary so line should be saved after execution

# %%
df_test # now  hassan drop because they have emplty space in place of age
# Out:
#       Name   Age
# 0    Ahmer  11.0
# 1  Mehmood  24.0
# 3   hamza   22.0

# %%
# chnage data type  
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  str
#  2   Product_ID        11239 non-null  str
#  3   Gender            11239 non-null  str
#  4   Age Group         11239 non-null  str
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  str
#  8   Zone              11239 non-null  str
#  9   Occupation        11239 non-null  str
#  10  Product_Category  11239 non-null  str
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), str(8)
# memory usage: 1.2 MB

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  str
#  2   Product_ID        11239 non-null  str
#  3   Gender            11239 non-null  str
#  4   Age Group         11239 non-null  str
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  str
#  8   Zone              11239 non-null  str
#  9   Occupation        11239 non-null  str
#  10  Product_Category  11239 non-null  str
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int64
# dtypes: int64(5), str(8)
# memory usage: 1.2 MB

# %%
# to check datatype of any column 
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns # check all columns  this showsall col list
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Relationship_Status', 'State', 'Zone', 'Occupation',
#        'Product_Category', 'Orders', 'Amount'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Relationship_Status', 'State', 'Zone', 'Occupation',
#        'Product_Category', 'Orders', 'Amount'],
#       dtype='str')

# %%
df = df.rename(columns={'Marital_Status':'Relationship_Status'})

# %%
df.describe()
# Out:
#             User_ID           Age  Relationship_Status        Orders  \
# count  1.125100e+04  11251.000000         11251.000000  11251.000000
# mean   1.003004e+06     35.421207             0.420318      2.489290
# std    1.716125e+03     12.754122             0.493632      1.115047
# min    1.000001e+06     12.000000             0.000000      1.000000
# 25%    1.001492e+06     27.000000             0.000000      1.500000
# 50%    1.003065e+06     33.000000             0.000000      2.000000
# 75%    1.004430e+06     43.000000             1.000000      3.000000
# max    1.006040e+06     92.000000             1.000000      4.000000
#
#              Amount
# count  11239.000000
# mean    9453.610858
# std     5222.355869
# min      188.000000
# 25%     5443.000000
# 50%     8109.000000
# 75%    12675.000000
# max    23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
import pandas as pd

# %%
# EXPLORATORY DATA ANALYSIS:---

sns.countplot(x='Gender',data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sales_gen = df.groupby(['Gender'],as_index=False )['Amount'].sum().sort_values (by='Amount',ascending=False)
sns.barplot(x='Gender', y ='Amount', data =sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
ax = sns.countplot(data=df,x='Age Group',hue ='Gender')
for bars  in ax.containers:
    ax.bar_label(bars)

# %%
# total amount vs  Age group 

sales_gen=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Age Group', y='Amount', data=sales_gen)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
 # State 

sales_state = (
    df.groupby(['Product_ID'], as_index=False)['Orders']
      .sum()
      .sort_values(by='Orders', ascending=False)
      .head(10)
)

sns.set(rc={'figure.figsize': (20, 5)})
sns.barplot(data=sales_state, x='Product_ID', y='Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# Top 10 most sold products
fig1, ax1 = plt.subplots(figsize=(12, 7))

df.groupby('Product_ID')['Orders'] \
    .sum() \
    .nlargest(10) \
    .sort_values(ascending=False) \
    .plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB
